# %%
import pandas as pd
import uuid
import json
import yaml
import random

df = pd.read_csv('../data/raw.csv')
meta = pd.read_csv('../data/feature_metadata.csv')

with open('../data/name_gen.yml') as f:
    names = yaml.safe_load(f)

df.rename(columns={k: v for k,v in meta[['SurveyKey', 'DataFrameKey']].values}, inplace=True)

# %%
distinct_values = {}
for col in df.columns:
    if col not in ('timestamp'):
        distinct_values[col] = pd.unique(df[col])

# %%
float('173.43')
# Out:
# 173.43

# %%
def clean_height(value):
    value = value.replace('cm', '')
    try:
        value = float(value)
        if 220 > value > 100:
            return value
    except:
        return None
    
def clean_sex(value):
    return {
        'Male': 'M',
        'Female': 'F'
    }[value]

def clean_weight(value):
    value = value.replace('kg', '')
    try:
        value = float(value)
        if 100 > value > 30:
            return value
    except:
        return None

def clean_wingspan(value):
    value = value.replace('cm', '')
    try:
        value = float(value)
        if 220 > value > 100:
            return value
    except:
        return None 

def clean_Vgrade(value):
    return int(value[1:])

def clean_I_dont(value):
    empty = (
        "I don't boulder",
        "I don't climb routes", 
    )
    if value in empty:
        value = None
    return value

def clean_list(value):
    empty = (
        "I don't train for endurance",
        "I don't hangboard",
        "No other strength training"
    )
    if value in empty:
        value = None
    else:
        value = value.split(', ')
    return value

def clean_maxload(value):
    value = value.replace('kg', '')
    try:
        value = float(value)
        if 70 > value:
            return value
    except:
        return None
    
def clean_activities(value):
    cats = {
        'yoga': ['yoga', 'yogs', 'yoha'],
        'stretching': ['stretching'],
        'mobility': ['mobility'],
        'pilates': ['pilates'],
        '"cardio"': ['cardio', 'stairs', 'jump rope', 'hiit running'], 
        'trail running': ['trail running'],
        'running': ['treadmill', 'running', 'jogging'],
        'mountain biking': ['mountain biking', 'MTB'],
        'biking': ['cycling', 'bike', 'spinning', 'BMX'],
        'hiking': ['hiking'],
        'walking': ['walking'],
        'acrobatics': ['gymnastics', 'trapeze', 'acro', 'parkour'],
        'martial arts': ['muay thai', 'grappling'],
        'calisthenics': ['calisthenics', 'ring work'],
        'weight training': ['weight lifting', 'weights', 'strongman', 'crossfit'],
        'soccer': ['soccer'],
        'skiing': ['ski'],
        'surfing': ['surfing'],
        'swimming': ['swimming'],
        'none': ['nope', 'non', 'fuck that', '0', 'na', 'none']
    }
    convert_cat = {}
    for act, v in cats.items():
        for kw in v:
            convert_cat[kw] = act

    singletons = [
        'rowing', 'volley', 'basket', 'squash', 'badminton', 'ultimate frisbee',
        'core', 'dance', 'paddling', 'sailing', 'skateboard', 'discgolf', 'skating'
    ]

    acts = []
    for act in value.split(', '):
        if act in convert_cat.keys():
            acts.append(convert_cat[act])
    return acts


rules = {
    'sex': clean_sex,
    'height': clean_height,
    'weight': clean_weight,
    'wingspan': clean_wingspan,
    # 'hardest_boulder_ever': clean_Vgrade,
    # 'hardest_boulder_recent': clean_Vgrade,
    # 'hardest_boulder_confident': clean_Vgrade,
    # 'hardest_route'
    'hangboard_grips': clean_list,
    'hangboard_style': clean_list,
    # 'halfcrimp_maxload': clean_maxload,
    # 'opencrimp_maxload': clean_maxload,
    'endurance_style': clean_list,
    'strength_style': clean_list,
    'other_activities': clean_activities
}

dont_trust = ['halfcrimp_maxload', 'opencrimp_maxload', 'opencrimp_minedge']
# Out:
# {'sex': array(['Male', 'Female'], dtype=object),
#  'height': array(['173', '180', '178', '184', '176', '186', '185', '175', '168',
#         '157.5', '163', '174', '188', '164', '190', '177', '179', '185.4',
#         '165.1', '157', '183', '167', '182', '170', '62', '193', '172.72',
#         '195', '165', '182.8', '171', '160', '172', '187.96', '181',
#         '1.68', '177.4', '191', '180.5', '153', '152', '194', '187', '154',
#         '180.3', '192', '190.5', '198', '167cm', '189',
#         '5 ft 8inches. Im amurican i dont know what centimeters are',
#         '196', '159.38', '166', '182.88', '1.67', '159', '173 cm', '162.5',
#         '172.7', '162', '177.8', '167.5', '155', '156', '169', '158',
#         '182.9', '177.5', '1295', '175.26', '162.56', '167.64', '168.5',
#         '185.3', '174.3', '110', '158.75', '201.1', '150', '8', '167.6',
#         '1.75'], dtype=object),
#  'weight': array(['77', '81', '67', '70', '84', '75', '88', '60', '80', '81.6', '54',
#         '50.8', '65', '100', '53', '63.5', '82', '66', '69', '47', '79.5',
#         '73', '86', '72', '64', '76', '177', '70.3', '85', '58', '172',
#         '79', '72.5', '79.3787', '74', '59', '56', '65.77', '66.5', '87',
#         '61.2', '55', '90', '56.7', '52', '71', '44', '68', '63', '78',
#         '77.5', '83.5', '73.5', '48.5', '73.4', '93', '79.4', '71.2', '50',
#         '60.5', '65.8', '45.5', '62', '51', '57', '160', '48', '65.7',
#         '95', '86.18', '62.6', '60.7', '83', '55.5', '74.8', '127',
#         '135 pounds....so....65 kg?', '78.7', '82,5', '51.7095', '72.5748',
#         '53.5', '89', '70 kg ', '51-53...', '58.5', '72 kg', '61', '64.5',
#         '71.67', '92', '158', '68.7', '81.6466', '132', '81.5', '42',
#         '79.8', '59.87419284', '77.1', '83.6', '153', '54.4', '77.5643',
#         '81.65', '74.5', '98', '64.41', '66kg', '~55', '88.45', '113',
#         '56.699', '66.22', '62.5', '130', '58.967', '73.3', '117', '140',
#         '65.5', '165', '175', '73.66', '78kg', '81.647', '180', '155',
#         '60.328', '67.2', '68.3', '45', '61.235', '61.7', '91.5', '61.6',
#         '58.96', '82.5', '49', '889', '38.4'], dtype=object),
#  'wingspan': array(['178', '180', '175', '197', '170', '181', '192', '-', '158', '165',
#         '195.6', '177', '186', '165.1', '155', '185', '190', '179', '173',
#         '182', '168', '187', '184', '193', '176', '189', '85', '172',
#         '183', '195', '185.5', '163', '171', '200', '196', '177.5',
#         'Dont know', '167', '194', '188', '190.5', '???', '157', '?',
#         'no idea', '172cm', '174', '110', nan, '166', '169', '161', '1.68',
#         '177.9', 'Not sure', '150', '199', "Don't know", '159', '191',
#         '180.3', 'unknown', '198', '167.5', '**', '74', '5 ft 10 inches',
#         '60', '170.7', '160', '152', '201', '203', '161??', '173 cm',
#         '177.8', '162', '193.4', '164', '198.12', 'Unknown', '130', 'idk',
#         '195.58', '78', '204', '160.6', '148', 'dunno', '76', '155 cm',
#         '208', '159.6', '1295', '0', '162.56', '185.928', '167.64', '144',
#         '80', '68', '152.4', '75', '191.7', '40', '1.8', '154'],
#        dtype=object),
#  'years_climbing': array(['4.5 - 5 years', '3 - 3.5 years', '.5 - 1 years', '9 - 9.5 years',
#         '6.5 - 7 years', '5 - 5.5 years', '1 - 1.5 years', '1.5 - 2 years',
#         '8.5 - 9 years', '5.5 - 6 years', '2.5 - 3 years', '3.5 - 4 years',
#         '2 - 2.5 years', '7.5 - 8 years', '12 - 12.5 years',
#         '4 - 4.5 years', '8 - 8.5 years', '0 - .5 years',
#         'More than 15 years', '14.5 - 15 years', '10 - 10.5 years',
#         '11.5 - 12 years', '10.5 - 11 years', '6 - 6.5 years',
#         '13 - 13.5 years', '7 - 7.5 years', '13.5 - 14 years',
#         '9.5 - 10 years', '11 - 11.5 years', '14 - 14.5 years',
#         '12.5 - 13 years'], dtype=object),
#  'indoor_outdoor': array(['Indoor and outdoor climbing', 'Indoor Climbing only',
#         'Outdoor Climbing only'], dtype=object),
#  'hardest_boulder_ever': array(['V8', 'V3', 'V7', 'V5', 'V10', 'V4', 'V2', 'V9', 'V6', 'V11',
#         "I don't boulder", 'V13', 'V1', 'V12', 'V0', 'V14'], dtype=object),
#  'hardest_boulder_recent': array(['V8', 'V3', 'V6', 'V4', 'V10', "I don't boulder", 'V5', 'V2', 'V7',
#         'V9', 'V13', 'V11', 'V12', 'V1', 'V0', 'V14'], dtype=object),
#  'hardest_boulder_confident': array(['V6', 'V1', 'V5', 'V3', 'V7', 'V2', 'V8', 'V4', 'V9',
#         "I don't boulder", 'V11', 'V0', 'V10'], dtype=object),
#  'hardest_route_ever': array(["I don't climb routes", '17', '21', '22', '23', '25', '30', '24',
#         '29', '31', '28', '27', '26', '20', '32', '33', '19', '13', '18',
#         '12', '15', '16', '11', '14'], dtype=object),
#  'hardest_route_recent': array(["I don't climb routes", '21', '22', '23', '29', '25', '20', '24',
#         '28', '26', '27', '17', '32', '18', '19', '13', '12', '30', '31',
#         '15', '33', '16', '11'], dtype=object),
#  'hardest_route_confident': array(["I don't climb routes", '19', '18', '21', '28', '22', '20', '23',
#         '26', '24', '16', '17', '15', '27', '30', '25', '31', '29', '13',
#         '11', '14', '32', '12'], dtype=object),
#  'weekly_count_climbing': array([4, 1, 3, 2, 6, 0, 5, 7]),
#  'weekly_hours_climbing': array([ 8,  3,  4,  6, 10,  0, 12,  1,  9,  5,  2,  7, 17, 11, 14, 16, 15,
#         20, 13, 24]),
#  'weekly_hours_training': array([ 6, 10,  3,  1,  2,  0,  8,  4,  7,  5, 12,  9, 14, 15, 11]),
#  'weekly_count_hangboard': array([0, 2, 1, 4, 3, 5, 6, 7]),
#  'hangboard_grips': array(["I don't Hangboard",
#         'Open Crimp, Front 3, Back 3, Middle 2, Slopers', 'Open Crimp',
#         'Half Crimp', 'Half Crimp, Open Crimp, Slopers',
#         'Full Crimp, Half Crimp, Open Crimp, Middle 2, Slopers',
#         'Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers',
#         'Open Crimp, Back 3, Front 2, Middle 2, Monos',
#         'Half Crimp, Front 3, Middle 2, Slopers', 'Half Crimp, Open Crimp',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers',
#         'Half Crimp, Front 3', 'Open Crimp, Front 2, Middle 2, Back 2',
#         'Half Crimp, Open Crimp, Front 3, Front 2, Middle 2, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Slopers, Pinch',
#         'Open Crimp, Front 3, Back 3',
#         'Half Crimp, Open Crimp, Front 3, Middle 2, Slopers',
#         'Full Crimp, Half Crimp, Open Crimp', 'Full Crimp, Half Crimp',
#         'Open Crimp, Front 3, Front 2, Slopers', 'Front 2, Back 2',
#         'Open Crimp, Front 2, Middle 2, Back 2, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Front 3', 'Half Crimp, Middle 2',
#         'Full Crimp, Half Crimp, Open Crimp, Front 2, Middle 2, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers, Pinch',
#         'Half Crimp, Middle 2, Slopers, Pinch', 'Full Crimp, Open Crimp',
#         'Open Crimp, Back 3, Middle 2',
#         'Full Crimp, Half Crimp, Open Crimp, Middle 2',
#         'Half Crimp, Open Crimp, Pinch', 'Half Crimp, Open Crimp, Back 2',
#         'Open Crimp, Front 3, Front 2, Middle 2, Slopers',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Front 2, Slopers, Monos',
#         'Full Crimp, Open Crimp, Front 3, Back 3, Slopers, Monos',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Middle 2, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Slopers', 'Half Crimp, Pinch',
#         'Half Crimp, Front 3, Slopers',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Slopers, Pinch',
#         'Full Crimp, Open Crimp, Front 3, Middle 2, Slopers',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Monos',
#         'Half Crimp, Open Crimp, Middle 2, Slopers, Pinch, Monos',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Back 2, Pinch',
#         'Open Crimp, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Middle 2, Slopers',
#         'Half Crimp, Front 3, Back 3, Front 2, Middle 2, Pinch',
#         'Half Crimp, Middle 2, Pinch', 'Half Crimp, Front 2, Back 2',
#         'Half Crimp, Front 2, Middle 2',
#         'Half Crimp, Open Crimp, Front 2, Middle 2, Slopers',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Slopers',
#         'Slopers, Pinch',
#         'Half Crimp, Open Crimp, Back 3, Middle 2, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Slopers',
#         'Full Crimp, Open Crimp, Front 2, Middle 2, Back 2',
#         'Half Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Front 2',
#         'Open Crimp, Slopers', 'Open Crimp, Front 3, Front 2, Middle 2',
#         'Half Crimp, Front 3, Front 2, Middle 2, Back 2, Pinch, Monos',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers, Monos',
#         'Full Crimp, Half Crimp, Front 3, Front 2, Back 2, Pinch',
#         'Half Crimp, Open Crimp, Middle 2',
#         'Half Crimp, Open Crimp, Front 3, Slopers',
#         'Half Crimp, Open Crimp, Front 3, Front 2, Middle 2',
#         'Open Crimp, Front 3, Slopers, Pinch, Monos',
#         'Half Crimp, Open Crimp, Middle 2, Pinch',
#         'Half Crimp, Front 3, Middle 2, Pinch',
#         'Half Crimp, Front 2, Middle 2, Back 2, Slopers',
#         'Full Crimp, Half Crimp, Back 2', 'Open Crimp, Front 3, Slopers',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Front 2, Middle 2, Slopers',
#         'Open Crimp, Front 2, Middle 2, Slopers, Monos', 'Slopers',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Monos',
#         'Half Crimp, Open Crimp, Front 3, Front 2, Middle 2, Slopers',
#         'Full Crimp, Half Crimp, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Slopers',
#         'Full Crimp, Front 3, Front 2, Middle 2, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Front 2, Middle 2, Back 2, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Slopers, Pinch, Monos',
#         'Open Crimp, Front 3, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Front 3, Monos',
#         'Half Crimp, Open Crimp, Front 3, Middle 2, Slopers, Pinch',
#         'Open Crimp, Pinch',
#         'Half Crimp, Open Crimp, Front 3, Front 2, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Slopers, Pinch',
#         'Open Crimp, Front 3, Back 3, Slopers',
#         'Open Crimp, Front 3, Back 3, Middle 2, Slopers, Pinch',
#         'Open Crimp, Middle 2',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Middle 2, Slopers, Pinch, Monos',
#         'Full Crimp, Middle 2, Slopers',
#         'Half Crimp, Open Crimp, Back 3, Slopers, Pinch',
#         'Open Crimp, Front 3, Middle 2, Pinch', 'Half Crimp, Monos',
#         'Half Crimp, Front 3, Front 2, Middle 2, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Slopers, Pinch',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Slopers, Pinch',
#         'Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers, Monos',
#         'Full Crimp', 'Back 3, Front 2, Slopers',
#         'Half Crimp, Open Crimp, Middle 2, Slopers, Pinch',
#         'Half Crimp, Open Crimp, Front 3, Pinch', 'Half Crimp, Slopers',
#         'Full Crimp, Front 3', 'Open Crimp, Back 3',
#         'Half Crimp, Front 3, Front 2, Middle 2, Slopers',
#         'Full Crimp, Open Crimp, Back 3, Front 2',
#         'Half Crimp, Open Crimp, Front 3, Middle 2, Back 2',
#         'Open Crimp, Front 3',
#         'Full Crimp, Half Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers, Monos',
#         'Half Crimp, Front 3, Middle 2, Monos',
#         'Half Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers',
#         'Half Crimp, Front 3, Back 3, Slopers',
#         'Half Crimp, Open Crimp, Front 3, Front 2, Middle 2, Slopers, Monos',
#         'Full Crimp, Half Crimp, Open Crimp, Front 3, Back 3, Front 2, Middle 2, Back 2, Slopers, Pinch, Monos',
#         'Half Crimp, Front 3, Pinch',
#         "Full Crimp, Half Crimp, Open Crimp, Slopers, Pinch, I don't Hangboard",
#         'Half Crimp, Front 2', 'Half Crimp, Back 2',
#         'Half Crimp, Open Crimp, Front 3, Back 3, Middle 2',
#         'Half Crimp, Open Crimp, Front 3, Middle 2',
#         'Open Crimp, Front 3, Front 2, Middle 2, Back 2, Slopers, Pinch',
#         'Half Crimp, Front 3, Back 3',
#         'Half Crimp, Open Crimp, Front 3, Slopers, Pinch',
#         'Half Crimp, Front 3, Middle 2'], dtype=object),
#  'hangboard_style': array(["I don't hangboard", 'Repeaters', 'Other protocol', 'Max weight',
#         'Min Edge, Other protocol', 'Min Edge, Repeaters',
#         'Max weight, Min Edge, Repeaters', 'Max weight, Min Edge',
#         'Max weight, Repeaters', 'Max weight, Min Edge, Other protocol',
#         'Max weight, Repeaters, Other protocol', 'Min Edge',
#         'Max weight, One arm hang program', '"no hangs"',
#         'Min Edge, Repeaters, Other protocol',
#         'Max weight, Repeaters, "no hangs"', 'Max weight, "no hangs"',
#         'Max weight, Min Edge, Repeaters, One arm hang program, Other protocol',
#         'One arm hang program', 'Repeaters, Other protocol',
#         'Max weight, Repeaters, One arm hang program',
#         'Max weight, Repeaters, One arm hang program, Other protocol',
#         'Max weight, Min Edge, Repeaters, One arm hang program',
#         'Repeaters, One arm hang program', 'Repeaters, "no hangs"',
#         'Max weight, Min Edge, Repeaters, One arm hang program, "no hangs"',
#         'Max weight, Min Edge, "no hangs"',
#         'Max weight, One arm hang program, "no hangs"',
#         'Max weight, Min Edge, One arm hang program',
#         'Min Edge, Repeaters, One arm hang program',
#         'Max weight, Min Edge, Repeaters, "no hangs", Other protocol',
#         'Max weight, Other protocol',
#         'Min Edge, One arm hang program, "no hangs"',
#         'Max weight, Min Edge, Repeaters, "no hangs"'], dtype=object),
#  'halfcrimp_maxload': array(['0', nan, '25', '15', '60', '22', '-', '50', '10', '14', '49.8',
#         '30', '62', '38.5', '5', '13', '53', '38 kg', '56', '29', '75',
#         "Can't do 18mm", '30 no hang', '9', '55', '35', '35+', '38.5 kg',
#         '22.68kg', '22.5', '11', '45', '10kg', '7', '27',
#         'not applicable ', '4.5', '16', 'N/a', '40', '6', '42', '18.5',
#         '10kg added weight ', '20', '18kg??', '-18', '18', 'unknown',
#         "Haven't tested", 'I dont add weight', '15,5', '50kg', '12.5',
#         '17', "I don't know.", '54', 'Na', '28', 'Not done before', '64',
#         '32', '23', '38', '55 lbs', 'I only open hand ', '+65lbs', '-9.5',
#         'na', '43', '20.14', '-10', 'One hand? Negative then', '~109kg',
#         '?', '86', '36', '120', '67kg', '39', '52.5', '27.21', '1', '46',
#         '57', '58', '60kg', '22.6', "I don't hangboard", '44', '15kg',
#         '7,5', '13.6', '-12kg one arm', '15 lbs', '30 kg added', '2.5',
#         '36.3', '90', '70', '21', '-6', '40kg', '7.5', '100', '36 kg',
#         '32kg', '41.25', '150', '65', '25kg', '16.5'], dtype=object),
#  'opencrimp_maxload': array(['0', '81kg', '25', nan, '50', '23', '-', '16', '35', '62', '30',
#         '55', '2', '80', '32', '50 kg', '10', '66', '17', '-20', 'unknown',
#         '70', "Can't do 18mm", '20 no hang', '28', '43', '35+', '55 kg',
#         '10kg', 'not applicable ', '15', '4', '20', '45', 'N/a', '3',
#         'I dont open crimp', '40.8', '47.6', '15kg?', '9',
#         "Haven't tested", 'I dont add weight', '5', '12', '18', '13',
#         "I don't know.", '40', 'Na', "Don't use open crimp", '27',
#         'Not done before', '64', '38', '75 lbs', '20.4',
#         '+30lbs (use a sloping edge though bam board)', '-6.8', 'na', '24',
#         '20.14', '-15', '38.5', '?', '95', '22', '36', '65kg', '39', '29',
#         '46', '41', "I don't hangboard", '44', '15kg', '10 lbs', '2.5',
#         '90', '-7', '35kg', '7.5', '123', 'Don’t know',
#         "I forget but I think it's stronger than open crimp", '41.25',
#         '100', '8'], dtype=object),
#  'halfcrimp_minedge': array(['0', nan, '8', '?', '6',
#         '14mm, can hang 8mm less than 10. No steps between', '-', '18',
#         '10mm', '10', '16', '5mm, 1KG', '8mm', '13 mm, 9 kg', '15',
#         'unknown', '20mm', '10 +13', '10mm, 5kg', '7mm + 7.5kg', '12', '7',
#         'not applicable ', 'Unknown', '6mm 10kg', '20', 'N/a',
#         '14mm, 27kg', '14mm, 47,5',
#         'Moon hangboard (advanced one) smallest edge, 30 kg added weight',
#         '190', "Haven't tested", '6mm', '17mm', '7mm, +20',
#         'Idk the really small one', '12, +0', 'unsure', '12mm, 7,5 kg',
#         "I don't know. I use a moon fingerboard and I rarely hang for 10 s.",
#         'Na', "10mm shouldn't add weight...", '14', "Didn't do min edge",
#         'Not done before', '8mm, +8', '8 mm', ' 6 mm 10 seconds',
#         '12mm +11.34kg', '8mm(rptc)', 'na', '6mm ', '14, 29', '8,+15',
#         '3mm', '5mm', '18mm', '25', '4', '13mm + 20kg', '12, 30', '17',
#         '18,+1', '14mm +5kg', '12mm + 40kg', '8mm, +5kg',
#         "I don't hangboard", '10mm +0kg', '8mm +10kg', '12mm +8kg 2 arm',
#         '11', '7mm 6.5', '8mm, 8kg', '8mm no added weight', '14, 16kg',
#         'unsure (rarely use min edge)', '7mm', '5', '8, 4', '8, +6',
#         '8mm +35kg'], dtype=object),
#  'opencrimp_minedge': array(['0', nan, '8', '?', '6', '14mm', '-', '18', '10', '14', '6mm, 5kg',
#         '9', '9mm', '13mm, 22.7 kg', '15', 'unknown', '20mm', '12 +25',
#         '10mm, 10kg', '7mm+ 12.5kg', '12', '8mm', 'not applicable ',
#         'Unknown', '5', '20', 'N/a', 'Never Tested', 'I dont open crimp',
#         '190', '18mm +9kg', "Haven't tested ", '12mm', '14, +0', 'unsure',
#         "I don't know. I use a moon fingerboard and I rarely hang for 10 s.",
#         'Na', "  10mm shouldn't add weight...", "Didn't do min edge", 'No',
#         'No idea ', '8 mm + 30 lbs 10 seconds', '18mm +18kg', '8mm(rptc)',
#         'na', '6mm', '18mm', '25', '13mm + 20kg', '12, 20', '17', '7',
#         '18,+10', '14mm +2kg', '5mm', '8mm, +5kg', '10mm',
#         "I don't hangboard", '8mm +5kg', '16mm', '11', '10 mm +21',
#         '8mm no added weight ', '312', 'Don’t know', '7mm', 'Idk',
#         'never tried'], dtype=object),
#  'weekly_count_campus': array([0, 1, 2, 3, 6, 4]),
#  'weekly_hours_campus': array([0, 1, 4, 2, 5, 3, 9]),
#  'weekly_count_endurance': array([1, 2, 0, 3, 4, 7, 6]),
#  'endurance_style': array(['4x4', 'Laps of routes', '4x4, ARC, route climbing intervals',
#         'Laps of routes, route climbing intervals',
#         '4x4, Max moves, threshold intervals',
#         "I don't train for endurance",
#         'Laps of routes, route climbing intervals, threshold intervals',
#         'ARC', 'hangboard repeater protocols, Laps of routes',
#         '4x4, Max moves, Laps of routes', 'ARC, route climbing intervals',
#         'Laps of routes, ARC', 'ARC, other',
#         "4x4, hangboard repeater protocols, Laps of routes, Feet on 'campusing'",
#         'systems boards', 'other', '4x4, Laps of routes',
#         '4x4, systems boards, Laps of routes, ARC',
#         'hangboard repeater protocols',
#         '4x4, Max moves, Laps of routes, ARC', 'threshold intervals',
#         '4x4, hangboard repeater protocols', "Feet on 'campusing'",
#         'Laps of routes, threshold intervals',
#         "Laps of routes, Feet on 'campusing'",
#         '4x4, systems boards, threshold intervals',
#         '4x4, hangboard repeater protocols, other',
#         'Max moves, Laps of routes',
#         'hangboard repeater protocols, ARC, route climbing intervals',
#         "4x4, hangboard repeater protocols, Max moves, Laps of routes, Feet on 'campusing', route climbing intervals",
#         '4x4, ARC', '4x4, threshold intervals, other',
#         'route climbing intervals, threshold intervals',
#         'threshold intervals, other', nan, '4x4, Max moves',
#         "I don't train for endurance, 4x4, hangboard repeater protocols, Max moves",
#         'hangboard repeater protocols, ARC', 'Laps of routes, other',
#         "hangboard repeater protocols, Max moves, Laps of routes, ARC, Feet on 'campusing', route climbing intervals",
#         '4x4, systems boards, Laps of routes, threshold intervals',
#         "I don't train for endurance, Laps of routes",
#         '4x4, Laps of routes, route climbing intervals',
#         '4x4, hangboard repeater protocols, Max moves, systems boards, Laps of routes, route climbing intervals',
#         "I don't train for endurance, 4x4, systems boards, Laps of routes",
#         '4x4, hangboard repeater protocols, ARC',
#         '4x4, Laps of routes, other', '4x4, ARC, threshold intervals',
#         'route climbing intervals', '4x4, route climbing intervals',
#         '4x4, hangboard repeater protocols, Max moves', 'Max moves, ARC',
#         'hangboard repeater protocols, Max moves, systems boards, Laps of routes',
#         '4x4, hangboard repeater protocols, route climbing intervals',
#         'Max moves',
#         "4x4, Max moves, systems boards, Laps of routes, ARC, Feet on 'campusing', route climbing intervals, threshold intervals, other",
#         'Max moves, systems boards, Laps of routes, route climbing intervals',
#         'Max moves, Laps of routes, ARC, threshold intervals',
#         'hangboard repeater protocols, systems boards, Laps of routes',
#         'systems boards, Laps of routes, route climbing intervals',
#         '4x4, Laps of routes, ARC', '4x4, systems boards, Laps of routes',
#         "Max moves, systems boards, Feet on 'campusing'",
#         'ARC, route climbing intervals, threshold intervals, other',
#         'hangboard repeater protocols, other', 'Max moves, other',
#         'hangboard repeater protocols, systems boards, Laps of routes, route climbing intervals',
#         '4x4, Laps of routes, threshold intervals',
#         '4x4, hangboard repeater protocols, systems boards, Laps of routes',
#         "I don't train for endurance, route climbing intervals",
#         '4x4, Laps of routes, ARC, route climbing intervals',
#         'Laps of routes, route climbing intervals, threshold intervals, other',
#         'hangboard repeater protocols, Max moves, systems boards, Laps of routes, route climbing intervals',
#         '4x4, threshold intervals', "ARC, Feet on 'campusing'",
#         "I don't train for endurance, other",
#         '4x4, systems boards, ARC, route climbing intervals',
#         "Laps of routes, ARC, Feet on 'campusing'",
#         "4x4, Feet on 'campusing'",
#         'hangboard repeater protocols, route climbing intervals, threshold intervals',
#         '4x4, Max moves, systems boards',
#         "Max moves, Laps of routes, Feet on 'campusing', route climbing intervals",
#         '4x4, systems boards',
#         '4x4, hangboard repeater protocols, systems boards',
#         '4x4, hangboard repeater protocols, systems boards, Laps of routes, ARC',
#         '4x4, hangboard repeater protocols, Laps of routes, ARC',
#         'hangboard repeater protocols, Laps of routes, ARC',
#         '4x4, systems boards, other',
#         '4x4, hangboard repeater protocols, Max moves, systems boards',
#         'hangboard repeater protocols, Max moves, ARC, route climbing intervals',
#         '4x4, Laps of routes, route climbing intervals, threshold intervals, other',
#         "4x4, Max moves, systems boards, Laps of routes, ARC, Feet on 'campusing'",
#         '4x4, hangboard repeater protocols, Max moves, Laps of routes',
#         "Laps of routes, Feet on 'campusing', route climbing intervals, threshold intervals, other",
#         'systems boards, Laps of routes, other',
#         'hangboard repeater protocols, systems boards',
#         'Laps of routes, ARC, route climbing intervals',
#         '4x4, hangboard repeater protocols, ARC, route climbing intervals',
#         '4x4, Max moves, systems boards, Laps of routes, route climbing intervals',
#         "I don't train for endurance, hangboard repeater protocols",
#         "hangboard repeater protocols, Max moves, systems boards, Laps of routes, Feet on 'campusing', route climbing intervals",
#         "I don't train for endurance, Max moves",
#         'hangboard repeater protocols, Laps of routes, route climbing intervals',
#         'systems boards, Laps of routes', 'Max moves, systems boards',
#         'Max moves, systems boards, other'], dtype=object),
#  'weekly_count_strength': array([3, 2, 0, 4, 1, 5, 6, 7]),
#  'session_hours_strength': array([ 4,  2,  0,  1,  6,  3,  5,  8,  7,  9, 10, 15, 12]),
#  'strength_style': array(['Antagonists, Legs, Core',
#         'Antagonists, Legs, Core, Upper body pulling, Upper body pushing',
#         'Antagonists, Core, Upper body pulling, Upper body pushing',
#         'Antagonists, Legs, Core, No other strength training',
#         'Core, Upper body pushing',
#         'Legs, Core, Upper body pulling, Upper body pushing', 'Core',
#         'No other strength training',
#         'Antagonists, Core, Upper body pulling',
#         'Core, Upper body pulling, Upper body pushing',
#         'Antagonists, Core, Upper body pushing',
#         'Legs, Upper body pulling, Upper body pushing',
#         'Legs, Core, Upper body pushing',
#         'Antagonists, Legs, Core, Upper body pushing',
#         'Antagonists, Legs, Upper body pulling', 'Antagonists, Core',
#         'Core, Upper body pulling',
#         'Antagonists, Legs, Upper body pulling, Upper body pushing',
#         'Antagonists',
#         'Antagonists, Upper body pulling, Upper body pushing',
#         'Antagonists, Legs, Core, Upper body pulling', 'Legs, Core',
#         'Legs, Core, Upper body pulling, No other strength training',
#         'Antagonists, Upper body pushing', 'Upper body pushing',
#         'Legs, Core, Upper body pulling', 'Legs',
#         'Upper body pulling, Upper body pushing',
#         'Antagonists, Upper body pulling', 'Upper body pulling',
#         'Antagonists, Legs, Upper body pushing', 'Antagonists, Legs'],
#        dtype=object),
#  'other_activities': array([nan, 'Yoga, stretching', 'soccer', 'Trail running', 'Cardio',
#         'HIIT Running', 'Cardio, skiing, mountainhiking', 'Running',
#         'Mountain biking', 'Calisthenics (or is this strength training?)',
#         'Running, bike', 'mobility', 'Running 10-15 miles/week',
#         'Strongman, crossfit, yoga.', 'Soccer', 'running', 'Cycling ',
#         'Cardio 2 times a week for 45 min. ', 'Yoga, pilates, running',
#         'running, football(soccer)', 'Cycling',
#         'Yoga 1xweek, light cardio 2xweek',
#         'Jogging, stretching, mobility on off days',
#         'indoor soccer/futball,  5 hours per week', 'Yoga daily ',
#         'Cycling, Hiking, Kayaking ', 'running, hiking',
#         'Sauna, ice baths, slackining', 'swimming, running, cycling',
#         'Running, Hiking', 'yoga', 'Static stretching ', 'Hiking',
#         'Rowing!', 'Some cardio, cycling',
#         'Very light cardio (fast walking, etc)',
#         '21h other sports (athletics, gymnastics, volley/basket/handball/soccer a week not counting climbing and weighttraining',
#         'mountain biking ', 'cycling, running', 'Disc Golf', 'cycling',
#         'Yoga, running', 'Yoga', 'ride a bike, video games',
#         'Running, yoga', 'Gymnastics, skiing, surfing',
#         'Biking 60 minutes a day', 'Muay Thai', 'running. Lots of running',
#         'Squash 1 time per week', 'Yoga, jogging, cycling, hiking ',
#         'MTB riding, trail running', 'Cardio yoga', 'Pilates',
#         'Yoga, soccer, cardio', 'Occasional Yoga', 'Running, stairs ',
#         'daily bike comuting', 'Stretching ', 'yoga, running',
#         '1hour cardio', 'N/a', 'Cardio, basketball',
#         'Yoga, cycling, trail running', 'Cardio, gymnastic stretching',
#         'Stretching, running', 'Yoga twice a week',
#         'surfing, mountain biking', 'none', 'stretching', 'bike, run',
#         'Walking', 'Treadmill/bike. ', 'Running a lot', 'BJJ',
#         'yoga, cycling', ' Cardio or hiking ', '-', 'basketball', 'cardio',
#         'Badminton', 'running, cycling', 'Weight Lifting',
#         'I jog on Rest days', 'Yoga, Jump rope', 'Spinning',
#         'xc skiing, biking, running, weights', 'LOADS OF CYCLING!!!',
#         'hiking, mountain biking (not in winter)',
#         'yoga / biking / cardio / running',
#         'Stretching, but not as much as I probably hsould',
#         'swimming, a little bit of cardio /not frequently',
#         'cario (ultimate frisbee)', 'Running & Cycling', 'Na',
#         'Pilates and running 25-30 km/week', 'Core',
#         'running twice a week up to 10 kms',
#         'yoga. want to will myself back into more cardio, not succeeded yet...',
#         'Stretching', 'yoga: 75 minutes 1x per week', 'Cardio, Trapeze',
#         'Yoga ', 'streching', 'Running 2x weekly', 'Yoga, cardio, skiing ',
#         'Light running/cycling, hiking about 1x/week', 'BMX',
#         'Exploring new bloc frontiers', 'Running, Jump Rope',
#         'Gymnastics training ', 'yoga and cardio', 'Ring work',
#         'Yoda, hiking, stairstepper/elliptical', 'Yoga, cardio',
#         'Yoga, bike', 'football', 'Slackline', '2-3 hrs hiking/week',
#         'Yoga, ski touring',
#         'my 1 hour of training is on a woodie... i guess that is really just more climbing really; I also try to run once a week but I hate it. ',
#         'yoga, cardio, stretch ruotines', 'Paddling', 'Yoga, hiking',
#         'Yoga biking', 'Cardio (HIIT & LISS)', 'Cycling.',
#         'run 2x per week', 'light cardio',
#         'Yoga, Weight Lifting, Running, Biking', 'Biking',
#         'Yoga, Running, Nordic Skiing, Basket ball, Biking', 'Bike',
#         'Nope', 'Acro-Yoga, Mountain Biking', 'Yoga, Running',
#         'yoga, dance, skiing', 'Non', 'Yogs', '12 oz biceps curls ;)',
#         'weight lifting', 'Heavy stretching ', 'yoga, lifting',
#         'Yoga 1-2x/week (usually recovery/restorative); mountain biking 0-1x week',
#         'yoga, soccer', 'walking', 'running, biking', 'yoga, cardio',
#         'fuck that', 'yoha', 'Trail Running, Stretching',
#         'Static stretching.', 'Bike riding', 'Yoga, mountain running',
#         'Cardio, yoga', 'Stretching 15 minutes per day', 'CARDIO',
#         'Football', 'cycling 30 mins/day', '0',
#         'yoga, cardio (running and cycling), setting', 'ski',
#         'Cardio, three times a week',
#         'weight training, & occasional misc sports',
#         'Yoga once a week, running 2-3 times per week',
#         'Bicycling, swimming', 'yoga, running, biking, soccer',
#         'Lots of Stretching, occasional 30 min run', 'Badminton, sailing',
#         'Walk', 'na', 'Streching', 'Weight lifting, cycling, skiing',
#         'Bicycling', '10 mile running across 2-3 days',
#         'mild cardio, stretching', 'Skateboard ',
#         'Bicycling, ultimate Frisbee',
#         'I run about 40 miles per week (>10 hours)', 'parkour',
#         'discgolf, skating, onewheeling', '312', 'Yoga, Cardio, Pilates',
#         'skiing', 'Yoga, trail run, mountain bike, uncle life',
#         'Running, biking, swimming, skiing', 'Skiing, running, swimming',
#         'Mountaineering', 'Hiking, running, mountain biking.',
#         'Biking, skiing', 'Grappling', 'Yoga, cycling',
#         'Cardio, cycling, calisthenics '], dtype=object),
#  'pullups_maxcount': array(['15', '11', '17', '8', nan, '9', '7', '12', '3', '35', '10', '>20',
#         '20', '5', '18', '13', '32', '25', '16', '1', '6',
#         "12?  I don't work on bodyweight pullups for reps.", '45', '30',
#         '2', '3 x 8', '23', '22', '15-20', '19', '14', '20?', 'maybe 5',
#         '50', 'Unsure', '24', '15?', "don't know", '74', '0',
#         '5, maybe, not sure', '21', '15+', '31',
#         'Not sure... probably 12-15?', 'approx 25', '4', '20+', 'Na',
#         '7?? ', '28', '25ish', 'Not calculated before', 'unsure', '100',
#         '8-12', '12+ (max Untested)', '?', '80', "i don't do this", 'idk',
#         '37', '55', '33', 'Unknown ', '27',
#         "The most I've gotten was 35ish but I don't usually try, it seems useless",
#         'Idk', '70', "Don't know", '25 maybe '], dtype=object),
#  'pullups_maxload': array(['29kg', '5kg', '20 kg', nan, '17,5kg', '25kg', '?', '65', '85 lbs',
#         '-', '15', '0', '10kg', '26lb', '30', '25', '35', '65#', '55',
#         '50', '20', 'N/a', '90lb', '32kg', '? dont work this.  10kg?',
#         '150', '106kg total (36kg added to BW)', '+45', '+40kg',
#         '195lbs total (including bodyweight) ',
#         '90kg bodyweight + 35kg =125kg', '16', '+16 kg', '+100 lbs',
#         '30+kg', '+37.5 kg', "Don't know", '27.22kg', '40kg', 'no idea',
#         '36', '80', 'BW+60lbs', '20kg', '45', '10', '7', 'Unsure', '12kg',
#         '135 lbs', '40', "i don't do weighted pull ups", 'Dont know',
#         '30kg', '10,5 kg', 'Dunno', '32', '27', '????', '31.75 kg',
#         '+20 kilo', 'what? weight?', '27.2', '16kgs', 'unknown',
#         '24 kg last time i checked ', '+40', 'BW + 40kg',
#         'Never do weighted pullups', '60', 'me + 30 lbs', '70lbs', 'none',
#         '+40lbs', 'not sure', '9kg', '+25 kg', '27 kg', '68+5kg', '17kg',
#         '20-25', 'ha! no need to train that yet', '8', 'unkown',
#         "Don't do these", '+20 lbs as of a year ago?',
#         'Not calculated before', '+30kg', '23', '34', '+40 lbs', '18kg',
#         '50 lbs', '0? no idea what this is. ', 'na', '24',
#         'Body weight + 35 lbs', '20 lbs', '40.82', '+50', '15kg', '4.5 kg',
#         '+ 55 lbs', '50lbs', '75', "I don't know", '95kg', '190', '8kg',
#         '21kg', '110 kg (incl. body weight)', '45lbs', '+80', '+50kg',
#         "I don't do this", '13', 'never tried', '57', '+35 kg', '35kilo',
#         '50kg', '45 lbs', '18 kg', '20lb', '+15 kg', '16kg', '+70 lbs',
#         '35lbs', '+10kg', '+60', '5', '35kg', '1', '15 kg', '40 kg',
#         '15 lbs', '+ 20 pounds', '28', '40 added', '32.5', 'Unknown',
#         '17.5', '103', 'Unknown unknown ', '70lb', "don't know", '70',
#         '25 kg', '25.5kg', '-10', '9', '32 kg', '90', '75lbs', '250',
#         '20.5 kg', '80lbs', '+25', '110', '33', '+18kg', ':(', '11',
#         '5x 38kg'], dtype=object),
#  'pushups_maxcount': array(['40', '24', nan, '30', '15', "Don't know", '25', '120', '10', '20',
#         '11', '50', '70', '22', '286', '115', '105', '30?',
#         '? 20 good one?  dont work for max numbers', '112', '33', '45',
#         '0', '35', '5', '3 x 8', 'Not sure', '50+', '42', '12', '70?',
#         'about 20', '46', '21', '80', 'lots?', '75', 'Unsure', '27', '?',
#         '15?', "don't know", '100', '36', '55', 'Dunno', '65', 'No clue',
#         '44', '60', '8', 'unknown', '-', 'About 30-40', '50-60', '14',
#         '12 handstand p/u', '3', '19', 'Na',
#         'surely under 15?? 10 in a set is suffice for suffering during workouts',
#         '28', 'Never tried this', 'Not calculated before', 'unsure',
#         '40ish', '17', '35-45', '31', '~30', '18', '95',
#         '25+ (max untested)', '30+', "I don't know", 'idk', '69', '4',
#         '118', '16', '40?', '52', '30ish', '10?', '137', '43', 'Unknown ',
#         '150', 'No idea', '39', 'Idk', '85', '70/1min', 'Dont know '],
#        dtype=object),
#  'lsit_maxtime': array(['30', '15sec', nan, '20', '5sec', '?', '0', '>20 sec',
#         '30 - one foot off.', '5', '20s', '5s', '2', '26 seconds',
#         '30 sec', '1:30', '4:30 min', '25', '60s',
#         '~8 seconds  (I train in cycles.  week is a bad unit since many things are not done every week)',
#         '24', '20 seconds', '45sec', '10 seconds', 'unknown', '3 minutes',
#         '10s', '30 secs', '15', '??', 'Not sure', '50 seconds', '20 sec',
#         "Don't know", '30sec', '15 s', '45s', 'no idea', "Don't know ",
#         '60 seconds', '30 seconds?', '1min', '35s', '60sefobds', 'Nil',
#         '1M', 'N/a', 'forever', "don't know", '10 sec (tucked)', '10',
#         '5 sec', '60', 'Dunno', '15s', '5 seconds', 'No clue', '18sec',
#         '30 s', '30s', 'Wtf is L sit?', '2 minutes', 'i suck!', 'unsure',
#         '32sec', '1 minute', 'No idea', '~1 min', '21', 'oooh...not sure',
#         '8 seconds', '1 min', 'unkown', 'Never tried this', '1 second',
#         'Not calculated before', 'No', '26s', '40', '100 sec',
#         '16 seconds', '25s ', '28 seconds', 'Floor: 25 seconds',
#         "0; definitely don't know what this is either. This survey makes me feel like I should be training...",
#         'na', '6', '-', '115', "I don't know", '30secs',
#         '35s+ (max untested)', '25 seconds', '45', 'fuck that', 'idk',
#         '23', '30 seconds', '1:21', '45 sec', '34', '2 minutes ', '3',
#         '5 seconds ', 'unknown ', '10 minutes', '1', 'Unknown ', '40s',
#         '8', '35', 'not sure', '0 minutes', '10000', '5:06', '7 sec', '4',
#         'all day lmao', 'Idk', '75', 'Probably a minute or two', '20S',
#         '1 sec', '11', 'No clue ', '1:15'], dtype=object)}

# %%
name_bank = [adj+' '+noun for adj in names['front'] for noun in names['back']]
cids = []
for i in range(len(df)):
    cid = random.choice(name_bank)
    cids.append(cid)
    name_bank.remove(cid)

df['cid'] = cids
